# %%
# Importing required libraries
import cv2
im = cv2.imread("E:/sonnet/images/1794292.jpg")

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plttest_x
import os

# %%
from os import listdir
from os.path import isfile, join
mypath="E:/sonnet/images"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
# Importing the train dataset
cat=pd.read_csv("E:/sonnet/train.csv")
im_list=[]
im_resize=[]
image=cat.iloc[:,0]
count=0
for i in image:
    if i in onlyfiles:
        im_list.append(cv2.imread(mypath+"/"+ i))
        im_resize.append(cv2.resize(im_list[count],(300,300)))
        count+=1

# %%
# Importing the test dataset
cat_test=pd.read_csv("E:/sonnet/test_ApKoW4T.csv")
im_list_test=[]
im_resize_test=[]
image=cat_test.iloc[:,0]
count=0
for i in image:
    if i in onlyfiles:
        im_list_test.append(cv2.imread(mypath+"/"+ i))
        im_resize_test.append(cv2.resize(im_list_test[count],(300,300)))
        count+=1

# %%
# Converting to array

# %%
import numpy as np
train_x = np.asarray(im_resize)
test_x = np.asarray(im_resize_test)

# %%
train_x=train_x.astype('float32')
test_x=test_x.astype('float32')
train_x=train_x/255
test_x=test_x/255

# %%
train_x.shape
# Out:
# (6252, 300, 300, 3)

# %%
train_y=cat.iloc[:,1].values.astype('int64')

# %%
train_y = keras.utils.to_categorical(train_y)

# %%
train_y=train_y[:,1:]

# %%
# checking the number of classes involved

# %%
num_classes = train_y.shape[1]

# %%
num_classes
# Out:
# 5

# %%
# Checking the images

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(im_resize_test[90])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# define the input shape of the image
input_shape=(300,300,3)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten,BatchNormalization
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3),strides=(1,1),padding="same",
                                                  activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3),strides=(1,1),padding="valid",
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3),strides=(1,1),padding="valid", activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))
model.add(BatchNormalization())
model.add(Conv2D(96, kernel_size=(3,3),strides=(1,1),padding="valid", activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3,3),strides=(1,1),padding="valid", activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(5, activation = 'softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 300, 300, 32)      896
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 150, 150, 32)      0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 150, 150, 32)      128
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 148, 148, 64)      18496
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 74, 74, 64)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 74, 74, 64)        256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 36, 36, 64)        256
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 34, 34, 96)        55392
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 17, 17, 96)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 17, 17, 96)        384
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 32)        27680
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 7, 7, 32)          128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               200832
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 342,021
# Trainable params: 341,445
# Non-trainable params: 576
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
## Define optimizer: Stochastic gradient descent 
from keras import optimizers
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# %%
# Compile model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
history = model.fit(train_x, train_y,
                    batch_size=30,
                    epochs=100,
                    verbose=1)
# Out:
# Epoch 1/100
# 6252/6252 [==============================] - 137s 22ms/step - loss: 0.2406 - acc: 0.9344
# Epoch 2/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.1542 - acc: 0.9514
# Epoch 3/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.1207 - acc: 0.9607
# Epoch 4/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.1103 - acc: 0.9650
# Epoch 5/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.1141 - acc: 0.9631
# Epoch 6/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.1098 - acc: 0.9631
# Epoch 7/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0876 - acc: 0.9715
# Epoch 8/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0947 - acc: 0.9699
# Epoch 9/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0742 - acc: 0.9768
# Epoch 10/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0814 - acc: 0.9736
# Epoch 11/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0732 - acc: 0.9773
# Epoch 12/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0742 - acc: 0.9739
# Epoch 13/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0654 - acc: 0.9776
# Epoch 14/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0648 - acc: 0.9782
# Epoch 15/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0889 - acc: 0.9707
# Epoch 16/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0689 - acc: 0.9762
# Epoch 17/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0521 - acc: 0.9805
# Epoch 18/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0553 - acc: 0.9824
# Epoch 19/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0603 - acc: 0.9773
# Epoch 20/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0734 - acc: 0.9774
# Epoch 21/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0701 - acc: 0.9795
# Epoch 22/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0664 - acc: 0.9757
# Epoch 23/100
# 6252/6252 [==============================] - 136s 22ms/step - loss: 0.0512 - acc: 0.9824
# Epoch 24/100
# 6252/6252 [==============================] - 135s 22ms/step - loss: 0.0546 - acc: 0.9827
# Epoch 25/100
# 4500/6252 [====================>.........] - ETA: 37s - loss: 0.0626 - acc: 0.9809
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-fc3a9e21a0a9> in <module>
#       2                     batch_size=30,
#       3                     epochs=100,
# ----> 4                     verbose=1)
#
# E:\Softwares\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# E:\Softwares\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# E:\Softwares\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# E:\Softwares\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# E:\Softwares\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# Model evaluation with test data set 
# Prediction at test data set
Y_pred = model.predict(test_x)

# %%
import math
data=pd.DataFrame(Y_pred)

# %%
data
# Out:
#                  0             1             2             3             4
# 0     3.719403e-05  2.782363e-04  2.208080e-06  9.995772e-01  1.050554e-04
# 1     3.359802e-18  5.844930e-24  7.618028e-30  1.000000e+00  7.294030e-31
# 2     1.525492e-12  2.254129e-14  6.829051e-20  1.000000e+00  1.543683e-20
# 3     6.635263e-08  9.999999e-01  1.627847e-16  5.919758e-11  7.647956e-16
# 4     4.424423e-01  3.876306e-01  1.013219e-02  1.558962e-01  3.898806e-03
# 5     2.225400e-18  1.600194e-19  5.796332e-22  1.000000e+00  1.252985e-22
# 6     5.533827e-16  2.216697e-19  5.577101e-24  1.000000e+00  2.112279e-24
# 7     1.176865e-09  9.999503e-01  4.787191e-16  4.968922e-05  2.041110e-10
# 8     9.783743e-05  9.998847e-01  2.051072e-10  1.738361e-05  2.010166e-10
# 9     4.014449e-08  1.688514e-12  4.745504e-11  1.000000e+00  9.446817e-15
# 10    5.557811e-11  6.727982e-14  1.896074e-16  1.000000e+00  4.268196e-22
# 11    5.467404e-13  1.549740e-15  5.143297e-17  1.000000e+00  1.316789e-14
# 12    1.173549e-19  1.157685e-24  2.898825e-28  1.000000e+00  1.173406e-25
# 13    8.100390e-03  9.808061e-01  1.370010e-06  1.100846e-02  8.360078e-05
# 14    1.625703e-09  1.000000e+00  2.558331e-20  2.503787e-12  5.130991e-13
# 15    9.416527e-01  5.740337e-02  6.381518e-07  4.878324e-07  9.428320e-04
# 16    2.884523e-05  9.996936e-01  1.431609e-08  2.774039e-04  1.370673e-07
# 17    1.051044e-05  9.999875e-01  3.879705e-12  1.532066e-06  4.202540e-07
# 18    1.702797e-08  1.000000e+00  1.067201e-18  2.755863e-12  1.126821e-15
# 19    1.001135e-12  4.091157e-13  1.965853e-15  1.000000e+00  1.097370e-18
# 2672  5.069905e-09  9.999709e-01  1.624211e-13  2.911225e-05  3.783518e-10
# 2673  1.264788e-09  1.000000e+00  5.160313e-18  1.106293e-09  5.736803e-12
# 2674  1.002126e-10  1.640615e-08  1.264718e-13  1.000000e+00  2.694541e-12
# 2675  5.476966e-09  1.709263e-08  1.819873e-14  1.000000e+00  2.452053e-10
# 2676  1.149297e-12  7.340366e-12  7.046343e-19  1.000000e+00  3.203578e-15
# 2677  4.496306e-18  5.762599e-30  8.006776e-22  1.000000e+00  9.268770e-29
# 2678  7.254522e-06  1.367935e-03  2.092468e-07  9.986244e-01  7.821867e-08
# 2679  9.857517e-01  7.487101e-04  1.132153e-02  2.139543e-03  3.853744e-05
#
# [2680 rows x 5 columns]

# %%
class_pred=[]
for i in range(len(data)):
    for j in range(5):
        if np.max(data.iloc[i,:])==data.iloc[i,j]:
            class_pred.append(j+1)

# %%
for i in range(len(class_pred)):
    if(class_pred[i]==1):
        print(i)
# Out:
# 68
# 74
# 124
# 233
# 269
# 299
# 309
# 316
# 347
# 534
# 535
# 536
# 547
# 548
# 549
# 552
# 553
# 555
# 558
# 561
# 562
# 563
# 564
# 565
# 567
# 583
# 585
# 586
# 588
# 598
# 600
# 601
# 602
# 603
# 613
# 614
# 615
# 617
# 624
# 626
# 627
# 630
# 632
# 633
# 636
# 651
# 659
# 669
# 670
# 674
# 678
# 683
# 687
# 691
# 692
# 700
# 701
# 702
# 703
# 704
# 705
# 706
# 708
# 711
# 712
# 713
# 716
# 719
# 720
# 721
# 722
# 728
# 730
# 733
# 736
# 740
# 751
# 756
# 758
# 762
# 763
# 764
# 768
# 772
# 773
# 774
# 775
# 782
# 785
# 791
# 792
# 793
# 794
# 795
# 800
# 802
# 806
# 811
# 814
# 816
# 823
# 824
# 826
# 828
# 829
# 831
# 838
# 841
# 849
# 852
# 856
# 861
# 862
# 863
# 864
# 865
# 867
# 875
# 881
# 882
# 883
# 884
# 887
# 890
# 894
# 898
# 899
# 913
# 914
# 918
# 919
# 920
# 927
# 944
# 948
# 950
# 951
# 952
# 953
# 956
# 958
# 962
# 965
# 966
# 967
# 968
# 970
# 975
# 979
# 981
# 984
# 987
# 993
# 995
# 1000
# 1001
# 1003
# 1005
# 1016
# 1019
# 1022
# 1023
# 1026
# 1028
# 1029
# 1030
# 1032
# 1033
# 1034
# 1035
# 1037
# 1039
# 1040
# 1042
# 1047
# 1048
# 1050
# 1051
# 1056
# 1057
# 1060
# 1066
# 1074
# 1080
# 1082
# 1086
# 1087
# 1090
# 1094
# 1100
# 1109
# 1120
# 1121
# 1122
# 1123
# 1126
# 1127
# 1130
# 1133
# 1134
# 1138
# 1140
# 1149
# 1151
# 1157
# 1159
# 1164
# 1168
# 1177
# 1179
# 1181
# 1182
# 1185
# 1186
# 1197
# 1200
# 1205
# 1206
# 1208
# 1211
# 1212
# 1213
# 1215
# 1216
# 1217
# 1221
# 1222
# 1225
# 1227
# 1236
# 1240
# 1246
